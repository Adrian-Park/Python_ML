# %% [markdown]
# <a href="https://colab.research.google.com/github/Adrian-Park/Python_ML/blob/main/prj01_news_category_classification_01_1_crawling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 네이버 뉴스 크롤링

# %% [markdown]
# ## 페이지 헤드라인 크롤링해오기

# %%
# 모듈 임포트
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %%
# 카테고리 설정
category = ['Politics', 'Economic', 'Social', 'Culture', 'World', 'IT']

# %%
# 크롤링할 주소
url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'

# %%
# 리스폰해오기
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.101 Safari/537.36"}
resp = requests.get(url, headers=headers)

# %%
# resp list 형식으로 출력
print(list(resp))
# Out:
# [b'\r\n\r\n\r\n\r\n<!DOCTYPE HTML>\r\n<html lang="ko">\r\n<head>\r\n<meta charset="euc-kr">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge"', b'>\r\n<meta name="referrer" contents="always">\r\n<meta http-equiv="refresh" content="600" />\r\n<meta name="viewport" content="width=1', b'106" />\r\n\r\n    \r\n    \r\n        \r\n            \r\n                \r\n                    \r\n                    \r\n                   ', b' \r\n                    \r\n                        \r\n\t                        \r\n\t\t                        \r\n\t\t                    ', b'    \r\n\t\t                        \r\n\t\t                    \r\n\t\t                    \r\n\t\t                    \r\n\t\t                    ', b'\r\n\t\t                    \r\n\t\t                    \r\n\t\t                    \r\n\t\t                \r\n                    \r\n            ', b'        \r\n                \r\n            \r\n            \r\n            \r\n            \r\n            \r\n        \r\n    \r\n    \r\n    \r\n  ', b'  \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n\r\n<meta property="og:title"       content="\xc1\xa4\xc4', b'\xa1 : \xb3\xd7\xc0\xcc\xb9\xf6 \xb4\xba\xbd\xba">\r\n<meta property="og:type"        content="website">\r\n<meta property="og:url"         content="http://news.nave', b'r.com/main/main.nhn?mode=LSD&mid=shm&sid1=100">\r\n<meta property="og:image"       content="https://ssl.pstatic.net/static.news/im', b'age/news/ogtag/navernews_200x200_20160804.png"/>\r\n<meta property="og:description" content="\xb1\xb9\xc8\xb8, \xc7\xe0\xc1\xa4, \xb1\xb9\xb9\xe6, \xbf\xdc\xb1\xb3 \xb5\xee \xc1\xa4\xc4\xa1 \xba\xd0\xbe\xdf \xb4', b'\xba\xbd\xba \xc1\xa6\xb0\xf8">\r\n<meta property="og:article:author"\tcontent="\xb3\xd7\xc0\xcc\xb9\xf6"/>\r\n\r\n<meta name="twitter:card"\t\tcontent="summary">\r\n<meta name="', b'twitter:title"\t\tcontent="\xc1\xa4\xc4\xa1 : \xb3\xd7\xc0\xcc\xb9\xf6 \xb4\xba\xbd\xba">\r\n<meta name="twitter:site"       content="\xb3\xd7\xc0\xcc\xb9\xf6 \xb4\xba\xbd\xba">\r\n<meta name="twitter:creat', b'or"    content="\xb3\xd7\xc0\xcc\xb9\xf6 \xb4\xba\xbd\xba">\r\n<meta name="twitter:image"\t\tcontent="https://ssl.pstatic.net/static.news/image/news/ogtag/naverne', b'ws_200x200_20160804.png">\r\n<meta name="twitter:description" content="\xb1\xb9\xc8\xb8, \xc7\xe0\xc1\xa4, \xb1\xb9\xb9\xe6, \xbf\xdc\xb1\xb3 \xb5\xee \xc1\xa4\xc4\xa1 \xba\xd0\xbe\xdf \xb4\xba\xbd\xba \xc1\xa6\xb0\xf8">\r\n\r\n\r\n\r\n\r\n\r\n', b'\r\n\r\n<title>\xc1\xa4\xc4\xa1 \xc8\xa8 : \xb3\xd7\xc0\xcc\xb9\xf6 \xb4\xba\xbd\xba\t</title>\r\n<link rel="shortcut icon" type="image/x-icon" href="https://ssl.pstatic.net/static.ne', b'ws/image/news/2014/favicon/favicon.ico" />\r\n\r\n\r\n\r\n\t\r\n\t\r\n\t\r\n\r\n\n\t\n\t\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pst', b'atic.net/static.news/pnews/resources/20210609_175517/css/common.css"/>\n\t\t<link rel="stylesheet" type="text/css" href="https://ss', b'l.pstatic.net/static.news/pnews/resources/20210609_175517/css/news.css"/>\n\t\t\n\t\t\n\t\n\t\n\n\r\n\r\n\r\n\r\n\r\n<script type="text/javascript" sr', b'c="https://ssl.pstatic.net/static.news/pnews/resources/20210609_175517/js/news.jindo.js" charset="euc-kr"></script>\r\n\r\n\r\n\n\n<scri', b'pt type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20210609_175517/js/news.jquery.js" charset="u', b'tf-8"></script>\n\n\n\n\n\n\t\n\t\n\t\n\t\n\t\n\t\n\t\t\n\t\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\t\n\t\n\t\n\n\n\n\n\t\n\t\t\n\t\t\n\t\t\t\n\t\t\n\t\n\n\n\n<script type="text/jav', b'ascript">\ndocument.domain=\'naver.com\';\nvar _MAIN_NEWS_MENU_ID=\'shm\';\nvar _MAIN_NEWS_SECTION_ID=\'103\';\nvar ccsrv=\'cc.naver.com\';\n', b"var g_ssc='news.sec';\nwindow.nsc = g_ssc; \nvar gnb_service='news';\nvar gnb_logout=encodeURIComponent(location.href);\nvar gnb_tem", b"plate='gnb_utf8';\nvar gnb_ ...

# %%
# resp 타입 확인
print(type(resp))
# Out:
# <class 'requests.models.Response'>

# %%
# BeautifulSoup으로 resp을 text로 변환
soup = BeautifulSoup(resp.text, 'html.parser') # html_parser로 파싱
print(soup)
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="정치 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="http://news.naver.com/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=100" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" property="og:image">
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="정치 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" name="twitter:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" name="twitter:description"/>
# <title>정치 홈 : 네이버 뉴스	</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20210609_175517/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20210609_175517/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20210609_175517/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20210609_175517/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# document.domain='naver.com';
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 1;
# var gnb_one_naver = 1;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Thu Jun 17 10:44:19 KST 2021";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20210609_175517/js/news.service.js" type="text/javascript"></script>
# </meta></meta></meta></meta></head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_wrap">
# <!-- GNB 마크업 -->
# <div id="gnb"></div>
# <!-- //GNB 마크업 -->
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(STA.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(STA.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="nclicks(STA.enter)" href="https://entertain.naver.com/home"><img alt="TV연예" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_entertain.png" width="52"/></a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.sports)" href="https://sports.news.naver.com"><img alt="스포츠" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_sports.png" width="48"/></a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.newsstand)" href="https://newsstand.naver.com"><img alt="뉴스스탠드" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_newsstand.png" width="77"/></a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.weather)" href="https://weather.naver.com"><img alt="날씨" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_weather.png" width="31"/></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(LNB.home)" href="/main/home.nhn"><span class="tx">뉴스홈</span> </a></li>
# <li><a class="nclicks(LNB.flash)" href="/main/list.nhn?mode=LSD&amp;mid=sec&amp;sid1=001"><span class="tx">속보</span></a></li>
# <li class="on"><a class="nclicks(LNB.pol)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(LNB.eco)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(LNB.soc)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(LNB.lif)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(LNB.wor)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(LNB.sci)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(LNB.opi)" href="/main/opinion/home.nhn"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(LNB.pho)" href="/main/photo/index.nhn?mid=pho"><span class="tx">포토</span> </a></li>
# <li><a class="nclicks(LNB.tv)" href="/main/tv/index.nhn?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(LNB.ranking)" href="/main/ranking/popularDay.nhn?mid=etc&amp;sid1=111"><span class="tx">랭킹뉴스</span> </a></li>
# </ul>
# <form accept-charset="UTF-8" action="https://search.naver.com/search.naver" id="lnb.searchForm" method="get" name="lnb_searchForm" target="_blank">
# <fieldset>
# <legend>뉴스 검색</legend>
# <input accesskey="s" class="text_index" name="query" style="ime-mode:active;" title="뉴스 검색" type="text"/>
# <input name="where" type="hidden" value="news"/>
# <input name="ie" type="hidden" value="utf8"/>
# <input name="sm" type="hidden" value="nws_hty"/>
# <button class="btn_search_lnb nclicks(LNB.search)" type="submit"><span class="tx"><span class="blind">검색</span></span></button>
# </fieldset>
# </form>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>06</strong>.<strong>17</strong><span class="day">(목)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li>
# <a class="nclicks(nct.right1)" href="https://news.naver.com/main/factcheck/main.nhn" title="팩트체크">팩트체크
# </a>
# </li>
# <li>
# <a class="nclicks(nct.right2)" href="https://media.naver.com/channel/settings.nhn  " target="_blank" title="언론사 구독 ">언론사 구독
# </a>
# </li>
# <li>
# <a class="nclicks(nct.right3)" href="https://news.naver.com/main/officeList.nhn" title="언론사 뉴스">언론사 뉴스
# </a>
# </li>
# <li class="end">
# <a class="nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리
# </a>
# </li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h2"><a class="nclicks(lmn_pol.home)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h2>
# <ul class="nav">
# <li><a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">청와대 </a></li>
# <li><a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당 </a></li>
# <li><a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">북한 </a></li>
# <li><a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">행정 </a></li>
# <li><a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">국방/외교 </a></li>
# <li><a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">정치일반 </a></li>
# <li><a class="snb_s18 nclicks(lmn_pol.mnl)" href="/main/list.nhn?mode=LSD&amp;mid=sec&amp;sid1=100">속보 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting.nhn?back=main" target="_blank"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn " href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=008&amp;aid=0004602453">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/008/2021/06/16/4602453.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=008&amp;aid=0004602453">윤석열측 "정치 선언 장소 호남 등 고려…공수처, 과도하게 무리"</a>
# <div class="cluster_text_lede">윤석열 전 검찰총장 측 이동훈 대변인은 6월말~7월초 사이에 윤 전 총장이 정치 참여를 선언할 것이라고 재확인하면서, 선언 장소로 호남 등을 고려하고 있 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004602453',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003516592',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">노컷뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=079&amp;aid=0003516592">"윤석열, 보수+중도+탈진보 묶는 압도적 정권교체 추구"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0010555129',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0010555129">'간보기' 끝낸 윤석열, 국민의힘 입당은 '오리무중'…왜?</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003110263',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0003110263">윤석열 측 "6말 7초 정치 선언…김종인, 함께하리라 믿는다"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.nhn?id=c_202106160910_00000053&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=008&amp;aid=0004602453"><span class="cluster_foot_more_icon_num">48</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=011&amp;aid=0003924630">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2021/06/17/3924630.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=011&amp;aid=0003924630">김남국 "이준석, 실패 사례 될 수도" 지적에 김용태 "조국 수호가 성공한 청년정치냐"</a>
# <div class="cluster_text_lede">'수술실 CCTV 설치법' 처리에 유보적인 입장을 밝힌 이준석 국민의힘 신임 당 대표를 겨냥, "청년정치 실패사례로 남게 될 수도 있다"고 지적한 김남국 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0003924630',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news015,0004563553',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=015&amp;aid=0004563553">김용태, 김남국 향해 "文정부 옹호가 성공적인 청년 정치냐"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news005,0001448411',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">국민일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=005&amp;aid=0001448411">김용태 “조국 수호대 김남국, 성공적인 청년 정치인이냐?”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0004921622',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아시아경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=277&amp;aid=0004921622">김용태, '이준석 비판' 김남국에 "내로남불·독선 옹호가 성공적인 청년 정치?"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.nhn?id=c_202106161910_00000067&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=011&amp;aid=0003924630"><span class="cluster_foot_more_icon_num">14</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003620455">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/023/2021/06/16/3620455.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003620455">[단독]‘당직자 폭행’ 송언석, 두 달 만에 국민의힘 ‘복당’ 신청</a>
# <div class="cluster_text_lede">4·7 재보궐선거 당일 당직자에게 폭언과 발길질을 해 물의를 일으켜 국민의힘에서 탈당했던 송언석 의원이 최근 ‘복당’ 신청서를 제출했다. 국민의힘 관계자 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003620455',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001602188',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001602188">'당직자 폭행' 송언석, 국민의힘 복당 신청</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0004658682',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">파이낸셜뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=014&amp;aid=0004658682">'당직자 폭행' 송언석, 두달만에 슬그머니 복당 신청</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0012464900',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0012464900">'당직자 폭행' 탈당 송언석, 국민의힘 복당 신청</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.nhn?id=c_202106161700_00000121&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003620455"><span class="cluster_foot_more_icon_num">18</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=009&amp;aid=0004810411">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/009/2021/06/17/4810411.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=009&amp;aid=0004810411">문 대통령 "조선왕국전도, 독도 한국 영토라는 소중한 자료"</a>
# <div class="cluster_text_lede">스페인을 국빈 방문 중인 문재인 대통령이 16일(현지시간) 스페인 상·하원 합동 연설 직후 스페인 상원 도서관을 찾아 '조선왕국전도'를 관람했다. 문 대 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0004810411',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0004959729',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">이데일리</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=018&amp;aid=0004959729">文대통령, 스페인서 ‘조선왕국전도’…“독도가 한국영토임 보여줘”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003620609',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003620609">스페인 방문 文대통령, 300년전 한반도 지도 보며 “독도는 한국 영토”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011065362',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">KBS</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=056&amp;aid=0011065362">조선왕국전도 본 문 대통령 “독도가  한국 영토라는 소중한 사료”</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.nhn?id=c_202106170330_00000022&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=009&amp;aid=0004810411"><span class="cluster_foot_more_icon_num">29</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0003110481">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/025/2021/06/16/3110481.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0003110481">황희 “한국-스페인 트래블버블 검토…단체관광 재개도 희망”</a>
# <div class="cluster_text_lede">문재인 대통령의 스페인 국빈방문을 수행 중인 황희 문화체육관광부 장관은 한국과 스페인의 ‘트래블 버블’ 협정 체결을 검토하고 있다고 밝혔다. 16일(현지 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003110481',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0012465203">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2021/06/16/12465203.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0012465203">문체장관 "스페인과 트래블버블 검토…7월부터 단체관광 희망"</a>
# <div class="cluster_text_lede">방역당국 너무 신중…실기하면 관광산업 데미지" 日 트래블버블 여부엔 "확진자 많고 접종 저조하지 않나" (마드리드·서울=연합뉴스) 공동취문재인 대통령의  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0012465203',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.nhn?id=c_202106141540_00000008&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0003110481"><span class="cluster_foot_more_icon_num">22</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=016&amp;aid=0001849528">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/016/2021/06/17/1849528.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=016&amp;aid=0001849528">정세균 “경제대통령” 내걸고 오늘 출마선언…‘지도자 도덕성’ 강조</a>
# <div class="cluster_text_lede">정세균 전 국무총리가 17일 ‘강한 대한민국, 경제 대통령’을 슬로건으로 내걸고 내년 대선 공식 출마를 선언한다. 이재명·이낙연·정세균 등 여권 내 ‘빅 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0001849528',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0012465554">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2021/06/17/12465554.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0012465554">정세균, 오늘 대권 출사표…경제대통령 비전 제시</a>
# <div class="cluster_text_lede">더불어민주당 대권주자인 정세균 전 국무총리가 17일 대선 출사표를 던진다. 정 전 총리는 이날 오후 2시 서울 마포구 상암동 누리꿈스퀘어에서 '강한 대한 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0012465554',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.nhn?id=c_202106151400_00000137&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=016&amp;aid=0001849528"><span class="cluster_foot_more_icon_num">15</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=028&amp;aid=0002548843">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/028/2021/06/16/2548843.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=028&amp;aid=0002548843">송영길 “청년 재난시대” 청년특임장관 신설 제안</a>
# <div class="cluster_text_lede">송영길 더불어민주당 대표가 16일 청년 문제를 총괄하는 청년특임장관 신설을 문재인 대통령에게 제안했다. 내년 대선의 핵심 ‘승부처’로 떠오른 2030세대 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news028,0002548843',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한겨레</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=009&amp;aid=0004810220">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/009/2021/06/16/4810220.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=009&amp;aid=0004810220">송영길 "청년특임장관 신설, 대통령에 제안"</a>
# <div class="cluster_text_lede">민주당 대표 국회 대표연설 송영길 더불어민주당 대표가 16일 국회 교섭단체 대표연설에서 "문재인 대통령에게 청년특임장관 신설을 제안한다"고 말했다. 송  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0004810220',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.nhn?id=c_202106161020_00000044&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=028&amp;aid=0002548843"><span class="cluster_foot_more_icon_num">48</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0012465415">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2021/06/16/12465415.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0012465415">문대통령 "한·스페인 놀랄 정도로 닮아…공동번영 미래 열 것"</a>
# <div class="cluster_text_lede">韓대통령 첫 스페인 의회 연설…"상호방문의 해 연장"스페인 상원의장 "금란지교…韓, 스페인의 우정 기대해도 좋다"스페인 상원 본회의장 들어선 문 대통령( …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0012465415',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=079&amp;aid=0003517147">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/079/2021/06/17/3517147.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=079&amp;aid=0003517147">바르셀로나 도착한 문대통령, 경제포럼에서 한-스페인 협력 강조</a>
# <div class="cluster_text_lede">스페인을 국빈방문 중인 문재인 대통령은 16일 오후(현지시간) 수도 마드리드에서 바르셀로나로 이동해 펠리페 6세 국왕의 초청으로 경제인연협회 연례포럼에</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003517147',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">노컷뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.nhn?id=c_202106152110_00001861&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0012465415"><span class="cluster_foot_more_icon_num">96</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=011&amp;aid=0003924634">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2021/06/17/3924634.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=011&amp;aid=0003924634">이준석 "차별금지법 원칙론 공감하지만 시기상조···사회적 논의 부족"</a>
# <div class="cluster_text_lede">이준석 국민의힘 대표가 17일 "차별금지법 제정은 시기상조"라는 입장을 밝혔다. 이 대표는 이날 BBS라디오에서 "차별 부분도 폭넓게 다루자는 원칙론에  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0003924634',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=047&amp;aid=0002316660">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/047/2021/06/17/2316660.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=047&amp;aid=0002316660">이준석 "차별금지법 제정, 서두를 필요 없다"</a>
# <div class="cluster_text_lede">보수진영 내 기독교적 관점 등으로 논의 혼재돼... 입법 단계까진 사회적 논의 부족" [이경태 기자] ▲ 국민의힘 이준석 대표와 김기현 원내대표 등 지도 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news047,0002316660',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">오마이뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.nhn?id=c_202106170930_00000016&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=011&amp;aid=0003924634"><span class="cluster_foot_more_icon_num">7</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0010556480">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2021/06/17/10556480.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0010556480">윤건영 "G7, 외신 주목도 높아…국내 언론은 무관심"</a>
# <div class="cluster_text_lede">문재인 대통령 유럽 순방에 특별수행원으로 동행한 윤건영 더불어민주당 의원은 17일 "문재인 대통령 주요 7개국(G7) 정상회담 관련 언론 보도가 너무 적 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0010556480',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0012465925">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2021/06/17/12465925.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0012465925">윤건영 "日스가, 약속장소에 안나오고 계속 말 바꿔"</a>
# <div class="cluster_text_lede">문대통령 순방 수행 중 라디오 인터뷰 "스가 의도적으로 피하는 인상…책임은 실무진에 전가" (서울=연합더불어민주당 윤건영 의원은 17일 주요 7개국(G7 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0012465925',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.nhn?id=c_202106170930_00002403&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0010556480"><span class="cluster_foot_more_icon_num">5</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001602441">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/052/2021/06/17/1602441.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001602441"> 카드 많이 쓰셨나요?..."현금으로 돌려줍니다"[자막뉴스]</a>
# <div class="cluster_text_lede">코로나19 백신 접종에 속도가 붙자, 민주당이 내수 경기 활성화에 팔을 걷어붙였습니다. 이른바 '3종 패키지' 추경 편성. 한마디로 나라 곳간을 풀어 지 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001602441',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0012463619">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2021/06/16/12463619.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0012463619">더 소비한 돈 일정부분 정부가 돌려준다…카드 캐시백 추진</a>
# <div class="cluster_text_lede">박용주 신용카드로 더 많은 소비를 하면 일정 부분을 정부가 돌려주는 방식의 소비 장려 방안이 당정 간에 추진되고 있다. 연말정산 과정에서 소득공제 형태로 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0012463619',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.nhn?id=c_202106161010_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001602441"><span class="cluster_foot_more_icon_num">46</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001602230">성김 美 대북대표 19일 방한...한미일 북핵 협의 추진</a>
# <div class="cluster_text_lede">성김 미 국무부 대북특별대표가 오는 19일부터 23일까지 4박 5일 일정으로 방한하는 일정을 조율하고 있다고 외교부가 밝혔습니다. 외교부 당국자는 성김 대표가 한미 정상회담 합의 내용을 신속하게 이행하기 위 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001602230',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=014&amp;aid=0004658572">성김 美 대북특별대표 19일 한국 온다</a>
# <div class="cluster_text_lede">성김 미 대북특별대표가 오는 19일 방한할 예정인 것으로 파악됐다. 외교 당국은 성김 대표 방한을 계기로 '한·미·일 북핵 수석대표 협의' 일정도 조율하고 있다고 밝혔다. 바이든 행정부 출범 후 대북특별대표 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0004658572',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">파이낸셜뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.nhn?id=c_202106160740_00000115&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001602230"><span class="cluster_foot_more_icon_num">34</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=015&amp;aid=0004563463">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/015/2021/06/16/4563463.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=015&amp;aid=0004563463">野 사무총장 한기호·정책위장 김도읍 내정</a>
# <div class="cluster_text_lede">국민의힘 신임 사무총장에 한기호 의원, 정책위원회 의장에 김도읍 의원이 내정된 것으로 알려졌다. 이준석 국민의힘 대표가 당 개혁 작업의 일환으로 계파색이 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news015,0004563463',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003620511">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/023/2021/06/17/3620511.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003620511">국민의힘 사무총장 한기호·정책위의장 김도읍 내정</a>
# <div class="cluster_text_lede">국민의힘 차기 사무총장과 정책위의장에 3선의 한기호(69·강원 춘천·철원·화천·양구을) 의원과 김도읍(57·부산 북·강서을) 의원이 각각 내정된 것으로  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003620511',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.nhn?id=c_202106161610_00000024&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=015&amp;aid=0004563463"><span class="cluster_foot_more_icon_num">33</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001602430">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/052/2021/06/17/1602430.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001602430">하태경, 안철수 측 '당명 교체' 요구에 "지지율 1등 된 당 이름을 왜?"</a>
# <div class="cluster_text_lede">하태경 국민의힘 의원이 합당 조건으로 '당명 교체'를 요구한 안철수 국민의당 대표를 향해 "황당한 일"이라고 비판했다. 하 의원은 17일 자신의 페이스북 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001602430',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0012465779">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2021/06/17/12465779.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0012465779">하태경 "安 '더 큰 2번' 만들겠다더니…또 말 바뀌나"</a>
# <div class="cluster_text_lede">국민의힘 하태경 의원은 17일 "국민의힘과 국민의당의 합당 논의가 안철수 대표의 난데없는 당명 변경 요구로 난항을 겪고 있다"고 비판했다. 대권 도전을  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0012465779',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# ...
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=024&amp;aid=0000069218&amp;rankingType=RANKING">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/024/2021/06/16/69218.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=024&amp;aid=0000069218&amp;rankingType=RANKING">비트코인→이더리움→카르다노…코인의 진화 아시나요</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.nhn?officeId=024"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/024/2020/12/23/logo_024_56_20201223182820.jpg" width="16"/></span>매경이코노미</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=310&amp;aid=0000088259&amp;rankingType=RANKING">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/310/2021/06/17/88259.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=310&amp;aid=0000088259&amp;rankingType=RANKING">국민의힘 최고위원 '여성 돌풍'… 조수진·배현진·정미경</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.nhn?officeId=310"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/310/2020/08/11/logo_310_56_20200811154942.png" width="16"/></span>여성신문</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=640&amp;aid=0000013050&amp;rankingType=RANKING">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/640/2021/06/16/13050.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=640&amp;aid=0000013050&amp;rankingType=RANKING">2021.06.17 Cartoon</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.nhn?officeId=640"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/640/2020/05/06/logo_640_56_20200506111106.png" width="16"/></span>코리아중앙데일리</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=648&amp;aid=0000001784&amp;rankingType=RANKING">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/648/2021/06/17/1784.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=648&amp;aid=0000001784&amp;rankingType=RANKING">대세인 줄 알았는데…친환경ETF, 수익률 파티 벌써 끝?</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.nhn?officeId=648"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/648/2021/04/20/logo_648_56_20210420164020.jpg" width="16"/></span>비즈니스워치</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">더보기</button>
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087473");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="da" id="doubleDA"></div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li>
# <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=028&amp;aid=0002548848" title="국민의힘 사무총장에 한기호 · 정책위의장에 김도읍 내정">국민의힘 사무총장에 한기호 · 정책위의장에 김도읍 내정</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=056&amp;aid=0011065375" title="한-스페인 ‘전략적 동반자 관계’ 격상…격리면제 여행권역 추진">한-스페인 ‘전략적 동반자 관계’ 격상…격리면제 여행권역 추진</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=022&amp;aid=0003591252" title="‘반문(反文) 빅텐트’ 구상 펼친 윤석열… 국민의힘과 본격 주도권 싸움">‘반문(反文) 빅텐트’ 구상 펼친 윤석열… 국민의힘과 본격 주도권 싸움</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=052&amp;aid=0001602446" title="프랑스, 오늘부터 실외 'No 마스크'...日 도쿄 긴급사태 연장 안 할 듯">프랑스, 오늘부터 실외 'No 마스크'...日 도쿄 긴급사태 연장 안 할 듯</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=001&amp;aid=0012465498" title='이란 대선 후보 3명 사퇴…"라이시 vs 헴마티 2파전"(종합)'>이란 대선 후보 3명 사퇴…"라이시 vs 헴마티 2파전"(종합)</a>
# </li>
# </ul>
# <ul class="list_txt">
# <li>
# <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=056&amp;aid=0011064558" title="가상화폐 거래소, ‘잡코인’ 상폐·유의종목 지정 잇따라">가상화폐 거래소, ‘잡코인’ 상폐·유의종목 지정 잇따라</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=119&amp;aid=0002502392" title="신한금융그룹, 신한퓨처스랩 7-2기 스타트업 모집">신한금융그룹, 신한퓨처스랩 7-2기 스타트업 모집</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=056&amp;aid=0011065019" title="주52시간제 상반된 설문…“계도 기간 달라” vs “유예 없다”">주52시간제 상반된 설문…“계도 기간 달라” vs “유예 없다”</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=105&amp;oid=018&amp;aid=0004959005" title="웹케시그룹, 특성화고 재학생 대상 장학금 신설…20명 장학금 전달">웹케시그룹, 특성화고 재학생 대상 장학금 신설…20명 장학금 전달</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=105&amp;oid=421&amp;aid=0005420083" title='"택시부터 비행기까지"…카카오T, 항공권 예매 서비스 시작'>"택시부터 비행기까지"…카카오T, 항공권 예매 서비스 시작</a>
# </li>
# </ul>
# <ul class="list_txt">
# <li>
# <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=052&amp;aid=0001602179" title='정은경 "3분기 백신 접종 50대 우선...나머지는 8월부터"'>정은경 "3분기 백신 접종 50대 우선...나머지는 8월부터"</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=014&amp;aid=0004658075" title='박범계 "검찰 조직개편, 유연성 발휘할 것"'>박범계 "검찰 조직개편, 유연성 발휘할 것"</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=021&amp;aid=0002474974" title="이천 쿠팡물류센터서 불…직원 240여 명 대피">이천 쿠팡물류센터서 불…직원 240여 명 대피</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=421&amp;aid=0005419904" title="&quot;취향대로 즐기세요&quot;…롯데호텔 서울, 여름철 별미 '냉면' 선봬">"취향대로 즐기세요"…롯데호텔 서울, 여름철 별미 '냉면' 선봬</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=082&amp;aid=0001099455" title="&quot;서비스 중단&quot; 국내 3대 서점 '반디앤루니스', 어음 못 갚아 결국 부도">"서비스 중단" 국내 3대 서점 '반디앤루니스', 어음 못 갚아 결국 부도</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/setting.nhn?back=main" target="_blank"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/assembly/index.nhn" target="_blank"> <img alt="내일을 여는 국민의 국회" border="0" class="banner" height="60" src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300"> </img></a>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.nhn?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"> </img></a>
# </div>
# </div>
# <div class="da" id="rightDoubleDA" style="display: none"></div>
# <script type="text/javascript">
#                 try{
#                     jindo.$("doubleDA").innerHTML = '<div id="daEtc_300250" name="daEtc_300250" style="width: 300px; height: 250px;"><iframe id="etc300250" name="etc300250" src="https://veta.naver.com/fxshow?su=SU10306&sid1=100&calp=shome" width="300" height="250" marginheight="0" marginwidth="0" border="0" frameborder="0" scrolling="no" align="center" title="우측_기타영역_더블플레이광고" data-veta-preview="news_home_02"></iframe></div>';
#                 }catch(e){}
#             </script>
# <div class="rightBottomDouble" style="margin-top:36px;"><div data-dom-type="doubleplay_bottom" id="doubleE300250" name="doubleE300250" title="더블플레이하단광고"></div></div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# <div class="index_myscrap">
# <a class="spr nclicks(fot.scrap)" href="/main/scrap/index.nhn">마이스크랩</a>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.nhn">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.nhn?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
# new news.lnb.NewsSearchController('lnb.searchForm');
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.nhn'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.nhn'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>

# %%
# 제목 html 가져오기
title_tags = soup.select('.cluster_text_headline') # class일 경우 앞에 .
print(title_tags)
# Out:
# [<a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=008&amp;aid=0004602453">윤석열측 "정치 선언 장소 호남 등 고려…공수처, 과도하게 무리"</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=079&amp;aid=0003516592">"윤석열, 보수+중도+탈진보 묶는 압도적 정권교체 추구"</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0010555129">'간보기' 끝낸 윤석열, 국민의힘 입당은 '오리무중'…왜?</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0003110263">윤석열 측 "6말 7초 정치 선언…김종인, 함께하리라 믿는다"</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=011&amp;aid=0003924630">김남국 "이준석, 실패 사례 될 수도" 지적에 김용태 "조국 수호가 성공한 청년정치냐"</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=015&amp;aid=0004563553">김용태, 김남국 향해 "文정부 옹호가 성공적인 청년 정치냐"</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=005&amp;aid=0001448411">김용태 “조국 수호대 김남국, 성공적인 청년 정치인이냐?”</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=277&amp;aid=0004921622">김용태, '이준석 비판' 김남국에 "내로남불·독선 옹호가 성공적인 청년 정치?"</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003620455">[단독]‘당직자 폭행’ 송언석, 두 달 만에 국민의힘 ‘복당’ 신청</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001602188">'당직자 폭행' 송언석, 국민의힘 복당 신청</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=014&amp;aid=0004658682">'당직자 폭행' 송언석, 두달만에 슬그머니 복당 신청</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0012464900">'당직자 폭행' 탈당 송언석, 국민의힘 복당 신청</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=009&amp;aid=0004810411">문 대통령 "조선왕국전도, 독도 한국 영토라는 소중한 자료"</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=018&amp;aid=0004959729">文대통령, 스페인서 ‘조선왕국전도’…“독도가 한국영토임 보여줘”</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003620609">스페인 방문 文대통령, 300년전 한반도 지도 보며 “독도는 한국 영토”</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=056&amp;aid=0011065362">조선왕국전도 본 문 대통령 “독도가  한국 영토라는 소중한 사료”</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0003110481">황희 “한국-스페인 트래블버블 검토…단체관광 재개도 희망”</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0012465203">문체장관 "스페인과 트래블버블 검토…7월부터 단체관광 희망"</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=016&amp;aid=0001849528">정세균 “경제대통령” 내걸고 오늘 출마선언…‘지도자 도덕성’ 강조</a>, <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://news.nav ...

# %%
# html에서 제목(헤드라인) 가져오기
titles = []
for title_tag in title_tags:
    # re를 이용하여 comile(세팅)함
    # 정규표현식 사용
    titles.append(re.compile('[^가-힣 | a-z | A-Z | 0-9]+').sub(' ', title_tag.text)) # 한글, 알파벳, 숫자을 제외하고 나머지 자리에는 공백

# 뽑아낸 데이터 및 갯수 확인
print(titles)
print(len(titles))
# Out:
# ['윤석열측  정치 선언 장소 호남 등 고려 공수처  과도하게 무리 ', ' 윤석열  보수 중도 탈진보 묶는 압도적 정권교체 추구 ', ' 간보기  끝낸 윤석열  국민의힘 입당은  오리무중 왜 ', '윤석열 측  6말 7초 정치 선언 김종인  함께하리라 믿는다 ', '김남국  이준석  실패 사례 될 수도  지적에 김용태  조국 수호가 성공한 청년정치냐 ', '김용태  김남국 향해  정부 옹호가 성공적인 청년 정치냐 ', '김용태  조국 수호대 김남국  성공적인 청년 정치인이냐 ', '김용태   이준석 비판  김남국에  내로남불 독선 옹호가 성공적인 청년 정치 ', ' 단독 당직자 폭행  송언석  두 달 만에 국민의힘  복당  신청', ' 당직자 폭행  송언석  국민의힘 복당 신청', ' 당직자 폭행  송언석  두달만에 슬그머니 복당 신청', ' 당직자 폭행  탈당 송언석  국민의힘 복당 신청', '문 대통령  조선왕국전도  독도 한국 영토라는 소중한 자료 ', ' 대통령  스페인서  조선왕국전도 독도가 한국영토임 보여줘 ', '스페인 방문  대통령  300년전 한반도 지도 보며  독도는 한국 영토 ', '조선왕국전도 본 문 대통령  독도가  한국 영토라는 소중한 사료 ', '황희  한국 스페인 트래블버블 검토 단체관광 재개도 희망 ', '문체장관  스페인과 트래블버블 검토 7월부터 단체관광 희망 ', '정세균  경제대통령  내걸고 오늘 출마선언 지도자 도덕성  강조', '정세균  오늘 대권 출사표 경제대통령 비전 제시', '송영길  청년 재난시대  청년특임장관 신설 제안', '송영길  청년특임장관 신설  대통령에 제안 ', '문대통령  한 스페인 놀랄 정도로 닮아 공동번영 미래 열 것 ', '바르셀로나 도착한 문대통령  경제포럼에서 한 스페인 협력 강조', '이준석  차별금지법 원칙론 공감하지만 시기상조 사회적 논의 부족 ', '이준석  차별금지법 제정  서두를 필요 없다 ', '윤건영  G7  외신 주목도 높아 국내 언론은 무관심 ', '윤건영  스가  약속장소에 안나오고 계속 말 바꿔 ', ' 카드 많이 쓰셨나요 현금으로 돌려줍니다 자막뉴스 ', '더 소비한 돈 일정부분 정부가 돌려준다 카드 캐시백 추진', '성김   대북대표 19일 방한 한미일 북핵 협의 추진', '성김   대북특별대표 19일 한국 온다', '  사무총장 한기호 정책위장 김도읍 내정', '국민의힘 사무총장 한기호 정책위의장 김도읍 내정', '하태경  안철수 측  당명 교체  요구에  지지율 1등 된 당 이름을 왜 ', '하태경    더 큰 2번  만들겠다더니 또 말 바뀌나 ', '이준석  차별금지법  시기 상조 차별에 보수 진영 확장된 논의 필요 ', ' 이상민   차별금지  골자  평등법  발의 범여권 24명 동참', '안철수  합당하면 당명 교체 당연  이준석  애초 협상안에 없던 요구 ', ' 당명 변경  놓고 삐걱대는 이준석 안철수 합당 논의 차질빚나', ' 국회M부스   차별금지법  찬성  반대    대선주자들에게 물었더니 ', ' 국회M부스    원내대표 2파전 윤호중 vs 박완주 쇄신책 차이는 ', ' 국회M부스   원문 공개   정보보고만 받았다 는 박형준 해명  신빙성은 ', ' 국회M부스  정당보조금 연간 9백억 시대 감사도 안 받는데 세금을 ']
# 44

# %%
# 데이터프레임 병합

# 빈 DF 생성
df_b = pd.DataFrame()
df_page2 = pd.DataFrame(titles, columns=['title'])
df_b = pd.concat([df_b, df_page2], axis='rows', ignore_index=True)
print(df_b.head())
print(df_b.info())
# Out:
#                                               title
# 0              윤석열측  정치 선언 장소 호남 등 고려 공수처  과도하게 무리
# 1                    윤석열  보수 중도 탈진보 묶는 압도적 정권교체 추구
# 2                    간보기  끝낸 윤석열  국민의힘 입당은  오리무중 왜
# 3                윤석열 측  6말 7초 정치 선언 김종인  함께하리라 믿는다
# 4  김남국  이준석  실패 사례 될 수도  지적에 김용태  조국 수호가 성공한 청년정치냐
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   44 non-null     object
# dtypes: object(1)
# memory usage: 480.0+ bytes
# None

# %% [markdown]
# ## 페이지 크롤링

# %%
# 정치 뉴스 페이지 url 확인
# 1 페이지 https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100#&date=%2000:00:00&page=1
# 2 페이지 https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100#&date=%2000:00:00&page=2
# 3 페이지 https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100#&date=%2000:00:00&page=3
# 4 페이지 https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100#&date=%2000:00:00&page=4

# 경제 뉴스 페이지 url 확인
# 1 페이지 https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=101#&date=%2000:00:00&page=1

# 사회 뉴스 페이지 url 확인
# 1 페이지 https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=102#&date=%2000:00:00&page=1

# 문화 뉴스 페이지 url 확인
# 1 페이지 https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=103#&date=%2000:00:00&page=1

# 세계 뉴스 페이지 url 확인
# 1 페이지 https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=104#&date=%2000:00:00&page=1

# IT 뉴스 페이지 url 확인
# 1 페이지 https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=1

# %%
# section_body > ul.type06_headline > li:nth-child(1) > dl > dt:nth-child(2) > a

# //*[@id="section_body"]/ul[1]/li[1]/dl/dt[2]/a

# /html/body/div[1]/table/tbody/tr/td[2]/div/div/div[5]/ul[1]/li[1]/dl/dt[2]/a

# %%
for j in range(0, 6):
    df_section_titles = pd.DataFrame()
    for i in range(1, 3):
        print('https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=10{0}#&date=%2000:00:00&page={1}'.format(j,i))
# Out:
# https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100#&date=%2000:00:00&page=1
# https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100#&date=%2000:00:00&page=2
# https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=101#&date=%2000:00:00&page=1
# https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=101#&date=%2000:00:00&page=2
# https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=102#&date=%2000:00:00&page=1
# https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=102#&date=%2000:00:00&page=2
# https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=103#&date=%2000:00:00&page=1
# https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=103#&date=%2000:00:00&page=2
# https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=104#&date=%2000:00:00&page=1
# https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=104#&date=%2000:00:00&page=2
# https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=1
# https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=2

# %%
# 정치 뉴스 페이지 모두 가져오기

# 각 뉴스마다 마지막 페이지가 다른 것을 처리
page_num = [334, 423, 400, 87, 128, 74]
df_title = pd.DataFrame()

for j in range(1,2):
    df_section_titles = pd.DataFrame()
    for i in range(1, page_num[j]): # page_num을 j로 인덱싱
        resp = requests.get('https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=10{0}#&date=%2000:00:00&page={1}'.format(j,i), headers=headers)
        # resp = requests.get(url+str(i), headers=headers)

        soup = BeautifulSoup(resp.text, 'html.parser')
        title_tags = soup.select('.cluster_text_headline')
        titles = []

        for title_tag in title_tags:
            titles.append(re.compile('[^가-힣 | a-z | A-Z | 0-9]+').sub(' ', title_tag.text))
        df = pd.DataFrame(titles, columns=['title'])
        print('.', end='') # 진행상황 확인 위해 for문 실행 시 . 출력, 줄바꿈 없애기 위해 end=''

        if i % 50 == 0:
            print('\n')
        # DF 병합
        df_section_titles = pd.concat([df_section_titles, df], 
                                    axis='rows', # deafult는 row라 생략 가능
                                    ignore_index=True)
        # 카테고리 추가
        df_section_titles['category'] = category[j] # j가 인덱스에 맞춰 category 리스트와 매칭
    df_title = pd.concat([df_title, df_section_titles], axis = 'rows', ignore_index=True)

print(df_title.head())
print(df_title.info())
# Out:
# ..................................................
#
# ..................................................
#
# ..................................................
#
# ..................................................
#
# ..................................................
#
# ..................................................
#
# ..................................................
#
# ..................................................
#
# ......................                                 title  category
# 0  공인회계사회장  감사부담 늘었다고 회계개혁 중단 어불성설 종합   Economic
# 1     감사위원회포럼  7월15일 내부회계관리제도 관련 정기 포럼  Economic
# 2   김영식 공인회계사회장  회계개혁 피로호소 불구 정도감사 원칙   Economic
# 3   감사위원회포럼  2021년 제2회 정기포럼  내달 15일 열어  Economic
# 4             건설업체  주 성정  이스타항공 인수하기로   Economic
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14348 entries, 0 to 14347
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     14348 non-null  object
#  1   category  14348 non-null  object
# dtypes: object(2)
# memory usage: 224.3+ KB
# None

# %%
df_title.to_csv('/content/naver_news_titles_210617_headline.csv')

# %% [markdown]
# ## 접어두기

# %%
df_title.iloc[150:160]

# %%
# 카테고리 추가
df_section_titles['category'] = 'Politics'
print(df_section_titles.head(20))
print(df_section_titles.info())

# %%
df_section_titles.head(50)
